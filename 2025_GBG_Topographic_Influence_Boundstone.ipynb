# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianMKelley/.doom.d/blob/main/2025_GBG_Topographic_Influence_Boundstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Import the data.

# %% [markdown]
# **Data stored in:**
# E:\Dropbox\Academic\Manuscripts\Manuscripts – Kelley\2025 GBG Topographic Inluence Boundstone Occurrence\Figures

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-68b012d2-96a4-4f3a-9f1b-b3bf69952603" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68b012d2-96a4-4f3a-9f1b-b3bf69952603">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
slope_relief_df = pd.read_excel("Slope-Relief Table clean.xlsx")
slope_relief_df
# Out:
#    Location               Platform                                   Area  \
# 0   Morocco       Djebel Bou Dahar                                    NaN
# 1   Morocco       Djebel Bou Dahar  Clinoforms overlying Phase 4 platform
# 2   Morocco       Djebel Bou Dahar     Clinoforms overlying Phase 4 slope
# 3   Morocco       Djebel Bou Dahar                                    NaN
# 4   Morocco       Djebel Bou Dahar                           South margin
# 5   Morocco       Djebel Bou Dahar                           North margin
# 6   Morocco       Djebel Bou Dahar                                    NaN
# 7   Morocco       Djebel Bou Dahar                                    NaN
# 8       NaN                    NaN                                    NaN
# 9     China  Great Bank of Guizhou                               Bianyang
# 10    China  Great Bank of Guizhou                               Bianyang
# 11    China  Great Bank of Guizhou                               Bianyang
# ...

# %%
slope_relief_df['Max relief']
# Out:
# 0      600.0
# 1       70.0
# 2      450.0
# 3      400.0
# 4        NaN
# 5      140.0
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13     200.0
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25     350.0
# 26     490.0
# 27     300.0
# 28     900.0
# 29     400.0
# 30       NaN
# 31    1000.0
# Name: Max relief, dtype: float64

# %%
ax1 = sns.boxplot(x="Facies Type", y="Max relief",
            data=slope_relief_df)

# %%
sns.set_theme()

# %%
ax = sns.scatterplot(data=slope_relief_df, x="Median relief", y="Median slope angle", hue="Facies Type")
#ax.invert_yaxis()

# %%
ax.figure.savefig('relief-slope-angle.pdf')
files.download('relief-slope-angle.pdf')
